# %%
import requests

# %%
import pandas as pd

# %%
base_url = "https://api.doge.gov/savings/leases"
headers = {
    "Accept": "application/json"
}

# %%
all_leases = []

# %%
page = 1

# %%
while True:
    params = {
        "page": page
    }
    response = requests.get(base_url, headers=headers, params=params)
    response.raise_for_status()
    data = response.json()

    leases = data.get("result", {}).get("leases", [])
    if not leases:
        break

    all_leases.extend(leases)
    print(f"Fetched page {page} with {len(leases)} leases.")

    total_pages = data.get("meta", {}).get("pages", 1)
    if page >= total_pages:
        break

    page += 1
# Out:
# Fetched page 1 with 100 leases.
# Fetched page 2 with 100 leases.
# Fetched page 3 with 100 leases.
# Fetched page 4 with 100 leases.
# Fetched page 5 with 100 leases.
# Fetched page 6 with 100 leases.
# Fetched page 7 with 53 leases.

# %%
doge_leases = pd.DataFrame(all_leases)

# %%
print(f"Total leases fetched: {len(doge_leases)}")
# Out:
# Total leases fetched: 653

# %%
doge_leases.head()
# Out:
#        date        location   sq_ft               description    value  \
# 0  4/4/2025    SAN JOSE, CA    5736                             308476
# 1  4/3/2025      ISELIN, NJ    5278  Termination via Mass Mod   158576
# 2  4/3/2025       PONCE, PR     270  Termination via Mass Mod    10727
# 3  4/3/2025   BALTIMORE, MD  103579  Termination via Mass Mod  2402919
# 4  4/3/2025  PORTSMOUTH, VA    1730  Termination via Mass Mod    37830
#
#    savings                                             agency
# 0   988813            EQUAL EMPLOYMENT OPPORTUNITY COMMISSION
# 1        0                               FED MED & CONCIL SRV
# 2    75119  EMPLOYMENT STANDARDS ADMINISTRATION, WAGE AND ...
# 3        0         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 4   189253                               FED MED & CONCIL SRV

# %%
doge_leases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653 entries, 0 to 652
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         653 non-null    object
#  1   location     653 non-null    object
#  2   sq_ft        653 non-null    int64
#  3   description  653 non-null    object
#  4   value        653 non-null    int64
#  5   savings      653 non-null    int64
#  6   agency       653 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 35.8+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
doge_leases["agency"].value_counts()
# Out:
# agency
# UNITED STATES FISH AND WILDLIFE SERVICE                    38
# NATURAL RESOURCES CONSERVATION SERVICE                     36
# MINE SAFETY HEALTH ADMINISTRATION                          34
# GEOLOGICAL SURVEY                                          33
# FOOD AND DRUG ADMINISTRATION                               27
# SMALL BUSINESS ADMINISTRATION                              23
# NATIONAL PARK SERVICE                                      22
# SOCIAL SECURITY ADMINISTRATION                             21
# EMPLOYMENT STANDARDS ADMINISTRATION, WAGE AND HOUR DIVI    20
# OCCUPATIONAL SAFETY AND HEALTH ADMINISTRATION              18
# BUREAU OF INDIAN AFFAIRS                                   18
# ANIMAL AND PLANT HEALTH INSPECTION SERVICE                 17
# NATIONAL OCEANIC ATMOSPHERIC ADMINISTRATION                15
# FARM SERVICE AGENCY - COUNTY                               15
# OFFICE OF THE SECRETARY                                    14
# FEDERAL HIGHWAY ADMINISTRATION                             11
# DEPARTMENTAL MANAGEMENT (IG)                               11
# FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION                10
# RURAL HOUSING SERVICE                                      10
# FOREST SERVICE                                             10
# INTERNATIONAL TRADE ADMINISTRATION                          9
# EQUAL EMPLOYMENT OPPORTUNITY COMMISSION                     8
# FARM SERVICE AGENCY- STATE                                  8
# UNITED STATES TRUSTEES                                      8
# NATIONAL LABOR RELATIONS BOARD                              8
# CORPS OF ENGINEERS, CIVIL                                   7
# DHS USSS                                                    7
# FED MED & CONCIL SRV                                        7
# DEPARTMENT OF EDUCATION                                     6
# ENVIRONMENTAL PROTECTION AGENCY                             6
# OFFICE OF INSPECTOR GENERAL                                 6
# INTERNAL REVENUE SERVICE NATIONAL OFFICE                    5
# DEFENSE CONTRACT MANAGEMENT AGENCY- NATIONAL                5
# BUREAU OF PRISONS                                           5
# AGRICULTURAL MARKETING SERVICE                              5
# BUREAU OF RECLAMATION                                       5
# EMPLOY. STANDARDS ADMIN., OFC OF WORKERS' COMP. PRGMS       4
# DEPARTMENT OF HOUSING AND URBAN DEVELOPMENT                 4
# U.S. IMMIGRATION & CUSTOMS ENFORCEMENT (ICE)                4
# EMPLOY. STANDARDS ADMIN., OFC OF CONTRACT COMPLIANCE PR     3
# EMPLOY. AND TRAIN. ADMIN., BUR. OF APPRENTICESHIP AND T     3
# BUREAU OF MINERALS MANAGEMENT SERVICE                       3
# FEDERAL ENERGY REGULATORY COMMISSION                        3
# HHS FDA                                                     3
# OFFICE OF THE INSPECTOR GENERAL                             3
# ALCOHOL  AND TOBACCO TAX  AND TRADE BUREAU                  3
# DHS UNDERSEC FOR MGM                                        3
# BUREAU OF LABOR STATISTICS                                  3
# DEFENSE COUNTERINTELLIGENCE AND SECURITY AGENCY – DOD W     2
# BUR OF INDUSTRY & SECURITY                                  2
# SECURITIES AND EXCHANGE COMMISSION                          2
# ID GEOLOGICAL SURVEY                                        2
# DOD WHS                                                     2
# DHS UNITED STATES SECRET SERVICE                            2
# NATIONAL ARCHIVES CENTERS                                   2
# FEDERAL TRADE COMMISSION                                    2
# BUR OF ALCOHOL,TOBACCO,FIREARMS & EXPLOSIVES                2
# OFFICE OF SURFACE MINING AND REGULATION ENFORCEMENT         2
# FEDERAL COMMUNICATIONS COMMISSION                           2
# DOE FERC                                                    2
# OFFICE OF THE SOLICITOR                                     2
# FAS- OFFICE SPAC                                            2
# FEDERAL RAILROAD ADMINISTRATION                             2
# DEF CONT MANA AGNEY                                         1
# PUBLIC BUILDINGS SERVICE-FIELD OFFICE                       1
# BANKRUPTCY CLERK                                            1
# DOD DCAA                                                    1
# PUBLIC DEFENDER SERVICE                                     1
# USDA FS                                                     1
# VBA                                                         1
# GAO                                                         1
# General Services Administration                             1
#                                                             1
# USDA FSIS                                                   1
# OFFICE OF MANAGEMENT                                        1
# SSA-OFFICE OF THE INSPECTOR GENERAL                         1
# AID                                                         1
# PROBATION                                                   1
# TD OFF CMPT CRRNCY                                          1
# DHS TSA                                                     1
# DRUG ENFORCEMENT ADMINISTRATION                             1
# DOD DISA                                                    1
# JD DRUG ENF                                                 1
# GOVERNMENT ACCOUNTABILITY OFFICE                            1
# USDA RMA                                                    1
# CENTER FOR DISEASE CONTROL                                  1
# DOD DEF CONT MGT AGY                                        1
# USA AFR                                                     1
# BU ALC TOB FRMS XPL                                         1
# FIELD OFFICES                                               1
# CD NOAA                                                     1
# USAF DEPT                                                   1
# FED MARITIME COMM                                           1
# VETERANS BENEFITS ADMINISTRATION                            1
# DOD JTO                                                     1
# ID FISH&WLF SRVC                                            1
# OFFICE OF LABOR MANAGEMENT STANDARDS                        1
# FTC                                                         1
# NATIONAL INDIAN GAMING COMMISSION                           1
# U.S. AGNY FOR GL MED                                        1
# BUREAU OF THE CENSUS                                        1
# DEPARTMENT OF HEALTH & HUMAN SERVICES                       1
# FED ACQUISITION SRVC, REG 05 FLEET MGMT FACILITIES          1
# NATIONAL APPEALS DIVISION                                   1
# EMPLOYEE BENEFITS SECURITY ADMIN                            1
# FOOD AND NUTRITION SERVICE (FNS)                            1
# BUREAU OF LAND MANAGEMENT                                   1
# OFFICE OF HEARING AND APPEALS                               1
# ALLOWANCE TO FORMER PRESIDENTS                              1
# FEDERAL LABOR RELATIONS AUTHORITY                           1
# SPECIAL INSPECTOR GENERAL FOR PANDEMIC RECOVERY             1
# DEPARTMENT OF JUSTICE                                       1
# OFFICE OF NATURAL RESOURCES AND REVENUE                     1
# DEPARTMENT OF AIR FORCE                                     1
# INSTITUTE MUSM SERV                                         1
# JOINT FORCES HEADQUARTERS NCR/MILITARY DC WASH              1
# CENTERS FOR MEDICARE AND MEDICAID SERVICES                  1
# FOOD SAFETY AND INSPECTION SERVICE                          1
# FEDERAL TRANSIT ADMINISTRATION                              1
# OFFICE OF PERSONNEL MANAGEMENT                              1
# MARITIME ADMINISTRATION                                     1
# DHS-CBP FIELD OPERATIONS FACILITIES                         1
# FPS-DHS-MGMT                                                1
# LD MINE SAFE HEALTH                                         1
# FEDERAL BUREAU OF INVESTIGATION                             1
# ARMY RECRUITING COMMAND                                     1
# FAS REG1 FLT MGT FAC                                        1
# FAS REG8 FLT MGT FAC                                        1
# BORDER PATROL FACILITIES                                    1
# UNITED STATES MARSHALS SERVICE                              1
# USDA AMS                                                    1
# SAVANNAH RIVER OPERATIONS OFFICE                            1
# FED ACQUISITION SRVC REG 04, FLEET MGMT FACILITIES          1
# OFFICE OF ADMINISTRATIVE LAW JUDGES                         1
# DEPT OF TREASURY-BUREAU OF THE FISCAL SERVICE               1
# FAS REG 09 MAINTENANCE CONTROL CENTER                       1
# PIPELINE & HAZARDOUS MATERIALS SAFETY ADMIN (PHMSA)         1
# DEPARTMENT OF LABOR                                         1
# STATE DEPT                                                  1
# Name: count, dtype: int64

# %%
doge_dot_leases = doge_leases[doge_leases['agency'].isin(['FEDERAL HIGHWAY ADMINISTRATION', 'FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION', 'FEDERAL RAILROAD ADMINISTRATION', 'PIPELINE & HAZARDOUS MATERIALS SAFETY ADMIN (PHMSA)', 'MARITIME ADMINISTRATION', 'FEDERAL TRANSIT ADMINISTRATION'])]

# %%
doge_dot_leases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 81 to 511
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         26 non-null     object
#  1   location     26 non-null     object
#  2   sq_ft        26 non-null     int64
#  3   description  26 non-null     object
#  4   value        26 non-null     int64
#  5   savings      26 non-null     int64
#  6   agency       26 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.6+ KB

# %%
agency_count = doge_dot_leases['agency'].value_counts()

# %%
agency_count
# Out:
# agency
# FEDERAL HIGHWAY ADMINISTRATION                         11
# FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION            10
# FEDERAL RAILROAD ADMINISTRATION                         2
# FEDERAL TRANSIT ADMINISTRATION                          1
# MARITIME ADMINISTRATION                                 1
# PIPELINE & HAZARDOUS MATERIALS SAFETY ADMIN (PHMSA)     1
# Name: count, dtype: int64

# %%
location_count = doge_dot_leases['location'].value_counts()

# %%
location_count
# Out:
# location
# SALEM, OR              2
# MADISON, WI            2
# CHARLESTON, WV         1
# CHICAGO, IL            1
# BOISE, ID              1
# LOS ANGELES, CA        1
# ONTARIO, CA            1
# NOGALES, AZ            1
# BEAUMONT, TX           1
# JEFFERSON CITY, MO     1
# TOPEKA, KS             1
# AMES, IA               1
# EWING TOWNSHIP, NJ     1
# ST. PAUL, MN           1
# SAN JUAN, PR           1
# OLYMPIA, WA            1
# CHEYENNE, WY           1
# MONTGOMERY, AL         1
# WILMINGTON, DE         1
# PRINCETON, NJ          1
# EAST PROVIDENCE, RI    1
# FORT WORTH, TX         1
# SANTA FE, NM           1
# HELENA, MT             1
# Name: count, dtype: int64

# %%
savings_sum_dot = doge_dot_leases['savings'].sum()

# %%
savings_sum_dot
# Out:
# np.int64(9713878)

# %%
sq_sum = doge_dot_leases['sq_ft'].sum()

# %%
sq_sum
# Out:
# np.int64(127222)

# %%
lease_cost_sum_dot = doge_dot_leases['value'].sum()

# %%
lease_cost_sum_dot
# Out:
# np.int64(3495562)

# %%
gsa_data = pd.read_excel('/Users/sogozalek/Desktop/Python/2025-4-11-iolp-leases.xlsx')

# %%
gsa_data.head()
# Out:
#   Location Code           Real Property Asset Name Installation Name  \
# 0        PA0656                   THE GATEWAY BLDG               NaN
# 1        AZ6769                BLM NAT'L TRAIN CTR               NaN
# 2        GA2170  56 PARK OF COMMERCE, SAVANNAH, GA               NaN
# 3        TX2983                    PROJECT TECH II               NaN
# 4        MO1915                850 NW CHIPMAN ROAD               NaN
#
#   Federal Leased Code  GSA Region            Street Address         City  \
# 0                   L           3               201 PENN ST      READING
# 1                   L           9           9828 N 31ST AVE      PHOENIX
# 2                   L           4  56 PARK OF COMMERCE BLVD     SAVANNAH
# 3                   L           7   3130 GENERAL HUDNELL DR  SAN ANTONIO
# 4                   L           6         850 NW CHIPMAN RD  LEES SUMMIT
#
#   State  Zip Code   Latitude   Longitude  Building Rentable Square Feet  \
# 0    PA     19601  40.335870  -75.933271                        54743.0
# 1    AZ     85051  33.575390 -112.127040                        72465.0
# 2    GA     31405  32.068700  -81.163241                        25524.0
# 3    TX     78226  29.381994  -98.560139                        85844.0
# 4    MO     64063  38.925870  -94.398908                       316318.0
#
#    Available Square Feet  Congressional District  \
# 0                    0.0                    4206
# 1                    0.0                     408
# 2                 4480.0                    1301
# 3                    0.0                    4823
# 4                    0.0                    2905
#
#   Congressional District Representative Lease Number Lease Effective Date  \
# 0                      CHRISSY HOULAHAN     LPA00132           2020-02-12
# 1                          DEBBIE LESKO     LAZ00614           2020-11-01
# 2                           EARL CARTER     LGA02806           2024-01-22
# 3                         TONY GONZALES     LTX00322           2022-01-28
# 4                       EMANUEL CLEAVER     LMO00226           2022-02-20
#
#   Lease Expiration Date Real Property Asset type
# 0            2035-02-11                 BUILDING
# 1            2032-10-31                 BUILDING
# 2            2029-01-21                 BUILDING
# 3            2037-01-27                 BUILDING
# 4            2042-02-19                 BUILDING

# %%
doge_dot_leases = doge_dot_leases.copy()

# %%
doge_dot_leases[['City', 'State']] = doge_dot_leases['location'].str.split(', ', expand=True)

# %%
doge_dot_leases
# Out:
#           date             location  sq_ft  \
# 81   2/28/2025       CHARLESTON, WV   1692
# 92   2/28/2025         ST. PAUL, MN   4246
# 102  2/28/2025         SANTA FE, NM   5847
# 106  2/28/2025       FORT WORTH, TX   5835
# 136  2/26/2025  EAST PROVIDENCE, RI   1556
# 140  2/26/2025        PRINCETON, NJ   3780
# 156  2/26/2025       WILMINGTON, DE   2950
# 174  2/26/2025       MONTGOMERY, AL   2662
# 209  2/26/2025          MADISON, WI   6254
# 210  2/26/2025          MADISON, WI   2477
# 237  2/26/2025         CHEYENNE, WY   2311
# 255  2/26/2025          OLYMPIA, WA   2069
# 282  2/25/2025         SAN JUAN, PR   4951
# 298  2/25/2025   EWING TOWNSHIP, NJ   7646
# 348  2/25/2025          CHICAGO, IL  13531
# 368  2/25/2025             AMES, IA  10056
# 373  2/25/2025           TOPEKA, KS   6572
# 381  2/25/2025   JEFFERSON CITY, MO   6440
# 413  2/25/2025         BEAUMONT, TX   2404
# 431  2/25/2025          NOGALES, AZ   2506
# 443  2/25/2025          ONTARIO, CA   8559
# 445  2/25/2025      LOS ANGELES, CA   7100
# 460  2/25/2025            BOISE, ID   5179
# 461  2/25/2025            SALEM, OR   6589
# 462  2/25/2025            SALEM, OR   2200
# 511  2/24/2025           HELENA, MT   1810
#
#                                 description   value  savings  \
# 81                 Termination via Mass Mod   51245   245978
# 92                 Termination via Mass Mod  114723   535585
# 102                Termination via Mass Mod  150950   732004
# 106                Termination via Mass Mod  157720   569522
# 136                Termination via Mass Mod   38867   126503
# 140                Termination via Mass Mod  111100   472706
# 156                Termination via Mass Mod   84288   280575
# 174                Termination via Mass Mod   59444   158626
# 209                Termination via Mass Mod  204103   408205
# 210                Termination via Mass Mod   50150   141656
# 237                Termination via Mass Mod   45187    53357
# 255                Termination via Mass Mod   60270   145639
# 282                Termination via Mass Mod  199214   215588
# 298                Termination via Mass Mod  216234   418843
# 348                Termination via Mass Mod  471820   943641
# 368                Termination via Mass Mod  216276   847327
# 373                Termination via Mass Mod  134940    12570
# 381                Termination via Mass Mod   83833    29858
# 413                Termination via Mass Mod   49665    17689
# 431                Termination via Mass Mod   68551   114001
# 443                Termination via Mass Mod  253213   427340
# 445                Termination via Mass Mod  313985   552270
# 460                Termination via Mass Mod  111193  1025719
# 461                Termination via Mass Mod  158557   927450
# 462                Termination via Mass Mod   50786   285097
# 511  True Termination- Agency Closed Office   39248    26129
#
#                                                 agency             City State
# 81         FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION       CHARLESTON    WV
# 92                      FEDERAL HIGHWAY ADMINISTRATION         ST. PAUL    MN
# 102                     FEDERAL HIGHWAY ADMINISTRATION         SANTA FE    NM
# 106                    FEDERAL RAILROAD ADMINISTRATION       FORT WORTH    TX
# 136        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION  EAST PROVIDENCE    RI
# 140        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION        PRINCETON    NJ
# 156                    FEDERAL RAILROAD ADMINISTRATION       WILMINGTON    DE
# 174        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION       MONTGOMERY    AL
# 209                     FEDERAL HIGHWAY ADMINISTRATION          MADISON    WI
# 210        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION          MADISON    WI
# 237        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION         CHEYENNE    WY
# 255        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION          OLYMPIA    WA
# 282                     FEDERAL HIGHWAY ADMINISTRATION         SAN JUAN    PR
# 298                     FEDERAL HIGHWAY ADMINISTRATION   EWING TOWNSHIP    NJ
# 348                     FEDERAL TRANSIT ADMINISTRATION          CHICAGO    IL
# 368                     FEDERAL HIGHWAY ADMINISTRATION             AMES    IA
# 373                     FEDERAL HIGHWAY ADMINISTRATION           TOPEKA    KS
# 381                     FEDERAL HIGHWAY ADMINISTRATION   JEFFERSON CITY    MO
# 413                            MARITIME ADMINISTRATION         BEAUMONT    TX
# 431        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION          NOGALES    AZ
# 443  PIPELINE & HAZARDOUS MATERIALS SAFETY ADMIN (P...          ONTARIO    CA
# 445                     FEDERAL HIGHWAY ADMINISTRATION      LOS ANGELES    CA
# 460                     FEDERAL HIGHWAY ADMINISTRATION            BOISE    ID
# 461                     FEDERAL HIGHWAY ADMINISTRATION            SALEM    OR
# 462        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION            SALEM    OR
# 511        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION           HELENA    MT

# %%
doge_dot_leases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 81 to 511
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         26 non-null     object
#  1   location     26 non-null     object
#  2   sq_ft        26 non-null     int64
#  3   description  26 non-null     object
#  4   value        26 non-null     int64
#  5   savings      26 non-null     int64
#  6   agency       26 non-null     object
#  7   City         26 non-null     object
#  8   State        26 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 2.0+ KB

# %%
city_state_combined = pd.merge(doge_dot_leases, gsa_data, on=['City', 'State'], how='inner')

# %%
filteredsq_combined_gsa_doge = city_state_combined[
    (city_state_combined['sq_ft'] == city_state_combined['Building Rentable Square Feet']) | 
    (city_state_combined['sq_ft'] == city_state_combined['Available Square Feet'])
]

# %%
filteredsq_combined_gsa_doge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 38 to 357
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   14 non-null     object
#  1   location                               14 non-null     object
#  2   sq_ft                                  14 non-null     int64
#  3   description                            14 non-null     object
#  4   value                                  14 non-null     int64
#  5   savings                                14 non-null     int64
#  6   agency                                 14 non-null     object
#  7   City                                   14 non-null     object
#  8   State                                  14 non-null     object
#  9   Location Code                          14 non-null     object
#  10  Real Property Asset Name               14 non-null     object
#  11  Installation Name                      0 non-null      object
#  12  Federal Leased Code                    14 non-null     object
#  13  GSA Region                             14 non-null     int64
#  14  Street Address                         14 non-null     object
#  15  Zip Code                               14 non-null     int64
#  16  Latitude                               14 non-null     float64
#  17  Longitude                              14 non-null     float64
#  18  Building Rentable Square Feet          14 non-null     float64
#  19  Available Square Feet                  14 non-null     float64
#  20  Congressional District                 14 non-null     int64
#  21  Congressional District Representative  14 non-null     object
#  22  Lease Number                           14 non-null     object
#  23  Lease Effective Date                   14 non-null     datetime64[ns]
#  24  Lease Expiration Date                  14 non-null     datetime64[ns]
#  25  Real Property Asset type               14 non-null     object
# dtypes: datetime64[ns](2), float64(4), int64(6), object(14)
# memory usage: 3.0+ KB

# %%
pd.set_option('display.max_columns', None)

# %%
filteredsq_combined_gsa_doge
# Out:
#           date            location  sq_ft  \
# 38   2/28/2025        SANTA FE, NM   5847
# 42   2/28/2025      FORT WORTH, TX   5835
# 56   2/26/2025       PRINCETON, NJ   3780
# 78   2/26/2025      MONTGOMERY, AL   2662
# 105  2/26/2025         MADISON, WI   6254
# 117  2/26/2025         MADISON, WI   2477
# 152  2/26/2025         OLYMPIA, WA   2069
# 205  2/25/2025         CHICAGO, IL  13531
# 213  2/25/2025            AMES, IA  10056
# 225  2/25/2025  JEFFERSON CITY, MO   6440
# 244  2/25/2025         NOGALES, AZ   2506
# 251  2/25/2025         ONTARIO, CA   8559
# 316  2/25/2025           BOISE, ID   5179
# 357  2/24/2025          HELENA, MT   1810
#
#                                 description   value  savings  \
# 38                 Termination via Mass Mod  150950   732004
# 42                 Termination via Mass Mod  157720   569522
# 56                 Termination via Mass Mod  111100   472706
# 78                 Termination via Mass Mod   59444   158626
# 105                Termination via Mass Mod  204103   408205
# 117                Termination via Mass Mod   50150   141656
# 152                Termination via Mass Mod   60270   145639
# 205                Termination via Mass Mod  471820   943641
# 213                Termination via Mass Mod  216276   847327
# 225                Termination via Mass Mod   83833    29858
# 244                Termination via Mass Mod   68551   114001
# 251                Termination via Mass Mod  253213   427340
# 316                Termination via Mass Mod  111193  1025719
# 357  True Termination- Agency Closed Office   39248    26129
#
#                                                 agency            City State  \
# 38                      FEDERAL HIGHWAY ADMINISTRATION        SANTA FE    NM
# 42                     FEDERAL RAILROAD ADMINISTRATION      FORT WORTH    TX
# 56         FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION       PRINCETON    NJ
# 78         FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION      MONTGOMERY    AL
# 105                     FEDERAL HIGHWAY ADMINISTRATION         MADISON    WI
# 117        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION         MADISON    WI
# 152        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION         OLYMPIA    WA
# 205                     FEDERAL TRANSIT ADMINISTRATION         CHICAGO    IL
# 213                     FEDERAL HIGHWAY ADMINISTRATION            AMES    IA
# 225                     FEDERAL HIGHWAY ADMINISTRATION  JEFFERSON CITY    MO
# 244        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION         NOGALES    AZ
# 251  PIPELINE & HAZARDOUS MATERIALS SAFETY ADMIN (P...         ONTARIO    CA
# 316                     FEDERAL HIGHWAY ADMINISTRATION           BOISE    ID
# 357        FEDERAL MOTOR CARRIER SAFETY ADMINISTRATION          HELENA    MT
#
#     Location Code                           Real Property Asset Name  \
# 38         NM1551                                  4001 OFFICE COURT
# 42         TX2500                                     OVERTON CENTRE
# 56         NJ4679  5 INDEPENDENCE WAY PRINCETON, NEW JERSEY 08540...
# 78         AL2244                                     520 COTTON GIN
# 105        WI1739                                   CITY CENTER WEST
# 117        WI1740                                    ONE POINT PLACE
# 152        WA8061                       MARKET PLACE OFFICE BUILDING
# 205        IL2177        CHICAGO IL (200 W ADAMS ST) BANK OF AMERICA
# 213        IA1318                                HINDERS & NETCOTT B
# 225        MO1947                                 3224 WEST EDGEWOOD
# 244        AZ7402                                  870 W. SHELL ROAD
# 251        CA7404                                   CENTRELAKE PLAZA
# 316        ID4265                                         WATERFRONT
# 357        MT5397                   FOREST SERVICE BUILDING - HELENA
#
#     Installation Name Federal Leased Code  GSA Region          Street Address  \
# 38                NaN                   L           7          4001 OFFICE CT
# 42                NaN                   L           7  4100 INTERNATIONAL PLZ
# 56                NaN                   L           2      5 INDEPENDENCE WAY
# 78                NaN                   L           4       520 COTTON GIN RD
# 105               NaN                   L           5         525 JUNCTION RD
# 117               NaN                   L           5              1 POINT PL
# 152               NaN                   L          10      724 COLUMBIA ST NW
# 205               NaN                   L           5          200 W ADAMS ST
# 213               NaN                   L           6              105 6TH ST
# 225               NaN                   L           6      3224 W EDGEWOOD DR
# 244               NaN                   L           9          870 W SHELL DR
# 251               NaN                   L           9     3401 CENTRE LAKE DR
# 316               NaN                   L          10    3050 N LAKEHARBOR LN
# 357               NaN                   L           8          2880 SKYWAY DR
#
#      Zip Code   Latitude   Longitude  Building Rentable Square Feet  \
# 38      87507  35.633120 -106.016330                         5847.0
# 42      76109  32.688880  -97.402571                         5835.0
# 56       8540  40.362560  -74.595211                         3780.0
# 78      36117  32.373050  -86.168091                         2662.0
# 105     53717  43.072160  -89.523941                         6254.0
# 117     53719  43.055899  -89.514126                         2477.0
# 152     98501  47.050762 -122.903920                         2069.0
# 205     60606  41.879720  -87.634061                        13531.0
# 213     50010  42.027230  -93.610961                        10056.0
# 225     65109  38.568953  -92.240591                         6440.0
# 244     85621  31.364726 -110.948980                         2506.0
# 251     91761  34.066470 -117.578380                         8559.0
# 316     83703  43.651566 -116.254080                         5179.0
# 357     59602  46.612190 -111.989000                         1810.0
#
#      Available Square Feet  Congressional District  \
# 38                     0.0                    3503
# 42                     0.0                    4812
# 56                     0.0                    3412
# 78                     0.0                     102
# 105                    0.0                    5502
# 117                    0.0                    5502
# 152                    0.0                    5310
# 205                    0.0                    1707
# 213                    0.0                    1904
# 225                    0.0                    2903
# 244                    0.0                     407
# 251                    0.0                     635
# 316                    0.0                    1602
# 357                    0.0                    3002
#
#     Congressional District Representative Lease Number Lease Effective Date  \
# 38                 TERESA LEGER FERNANDEZ     LNM00471           2020-11-06
# 42                            KAY GRANGER     LTX17093           2014-08-11
# 56                  BONNIE WATSON COLEMAN     LNJ00425           2020-01-01
# 78                            BARRY MOORE     LAL01036           2018-06-01
# 105                            MARK POCAN     LWI19408           2017-10-01
# 117                            MARK POCAN     LWI19530           2018-07-28
# 152                    MARILYN STRICKLAND     LWA00110           2018-03-01
# 205                           DANNY DAVIS     LIL18980           2017-09-01
# 213                        RANDY FEENSTRA     LIA21017           2014-08-01
# 225                    BLAINE LUETKEMEYER     LMO41044           2016-01-09
# 244                         RAÚL GRIJALVA     LAZ02947           2012-05-01
# 251                          NORMA TORRES     LCA02766           2012-05-10
# 316                       MICHAEL SIMPSON     LID07447           2014-11-20
# 357                     MATTHEW ROSENDALE     LMT14907           2015-09-01
#
#     Lease Expiration Date Real Property Asset type
# 38             2030-11-05                 BUILDING
# 42             2029-08-10                 BUILDING
# 56             2029-12-31                 BUILDING
# 78             2028-05-31                 BUILDING
# 105            2027-09-30                 BUILDING
# 117            2028-07-27                 BUILDING
# 152            2028-02-29                 BUILDING
# 205            2027-08-31                 BUILDING
# 213            2029-07-31                 BUILDING
# 225            2026-01-08                 BUILDING
# 244            2027-04-30                 BUILDING
# 251            2027-05-09                 BUILDING
# 316            2034-11-19                 BUILDING
# 357            2026-02-28                 BUILDING

# %%
filtered_unclear_doge_leases = doge_leases[doge_leases['agency'].isin(['OFFICE OF THE SECRETARY', 'DEPARTMENTAL MANAGEMENT (IG)', 'OFFICE OF INSPECTOR GENERAL', 'OFFICE OF THE INSPECTOR GENERAL', 'FIELD OFFICES', 'OFFICE OF HEARING AND APPEALS', 'OFFICE OF MANAGEMENT', 'FAS REG 09 MAINTENANCE CONTROL CENTER', 'FAS, REG 01 FLEET MANAGEMENT FACILITIES'])]

# %%
filtered_unclear_doge_leases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 22 to 630
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         38 non-null     object
#  1   location     38 non-null     object
#  2   sq_ft        38 non-null     int64
#  3   description  38 non-null     object
#  4   value        38 non-null     int64
#  5   savings      38 non-null     int64
#  6   agency       38 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.4+ KB

# %%
filtered_unclear_doge_leases = filtered_unclear_doge_leases.copy()

# %%
filtered_unclear_doge_leases[['City', 'State']] = filtered_unclear_doge_leases['location'].str.split(', ', expand=True)

# %%
unclear_combined = pd.merge(filtered_unclear_doge_leases, gsa_data, on=['City', 'State'], how='inner')

# %%
filteredsq_unclear_combined = unclear_combined[
    (unclear_combined['sq_ft'] == unclear_combined['Building Rentable Square Feet']) | 
    (unclear_combined['sq_ft'] == unclear_combined['Available Square Feet'])
]

# %%
filteredsq_unclear_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 192 to 1067
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   20 non-null     object
#  1   location                               20 non-null     object
#  2   sq_ft                                  20 non-null     int64
#  3   description                            20 non-null     object
#  4   value                                  20 non-null     int64
#  5   savings                                20 non-null     int64
#  6   agency                                 20 non-null     object
#  7   City                                   20 non-null     object
#  8   State                                  20 non-null     object
#  9   Location Code                          20 non-null     object
#  10  Real Property Asset Name               20 non-null     object
#  11  Installation Name                      0 non-null      object
#  12  Federal Leased Code                    20 non-null     object
#  13  GSA Region                             20 non-null     int64
#  14  Street Address                         20 non-null     object
#  15  Zip Code                               20 non-null     int64
#  16  Latitude                               20 non-null     float64
#  17  Longitude                              20 non-null     float64
#  18  Building Rentable Square Feet          20 non-null     float64
#  19  Available Square Feet                  20 non-null     float64
#  20  Congressional District                 20 non-null     int64
#  21  Congressional District Representative  20 non-null     object
#  22  Lease Number                           20 non-null     object
#  23  Lease Effective Date                   20 non-null     datetime64[ns]
#  24  Lease Expiration Date                  20 non-null     datetime64[ns]
#  25  Real Property Asset type               20 non-null     object
# dtypes: datetime64[ns](2), float64(4), int64(6), object(14)
# memory usage: 4.2+ KB

# %%
blank_cells = doge_leases[doge_leases["agency"].str.strip() == ""]

# %%
blank_cells
# Out:
#           date    location  sq_ft                             description  \
# 563  2/12/2025  LORTON, VA  15280  True Termination- Agency Closed Office
#
#       value  savings agency
# 563  342689        0

# %%
blank_cells = blank_cells.copy()

# %%
blank_cells[['City', 'State']] = blank_cells['location'].str.split(', ', expand=True)

# %%
blank_cells_combined = pd.merge(blank_cells, gsa_data, on=['City', 'State'], how='inner')

# %%
blank_cells_sq_combined = blank_cells_combined[
    (blank_cells_combined['sq_ft'] == blank_cells_combined['Building Rentable Square Feet']) | 
    (blank_cells_combined['sq_ft'] == blank_cells_combined['Available Square Feet'])
]

# %%
blank_cells_sq_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   0 non-null      object
#  1   location                               0 non-null      object
#  2   sq_ft                                  0 non-null      int64
#  3   description                            0 non-null      object
#  4   value                                  0 non-null      int64
#  5   savings                                0 non-null      int64
#  6   agency                                 0 non-null      object
#  7   City                                   0 non-null      object
#  8   State                                  0 non-null      object
#  9   Location Code                          0 non-null      object
#  10  Real Property Asset Name               0 non-null      object
#  11  Installation Name                      0 non-null      object
#  12  Federal Leased Code                    0 non-null      object
#  13  GSA Region                             0 non-null      int64
#  14  Street Address                         0 non-null      object
#  15  Zip Code                               0 non-null      int64
#  16  Latitude                               0 non-null      float64
#  17  Longitude                              0 non-null      float64
#  18  Building Rentable Square Feet          0 non-null      float64
#  19  Available Square Feet                  0 non-null      float64
#  20  Congressional District                 0 non-null      int64
#  21  Congressional District Representative  0 non-null      object
#  22  Lease Number                           0 non-null      object
#  23  Lease Effective Date                   0 non-null      datetime64[ns]
#  24  Lease Expiration Date                  0 non-null      datetime64[ns]
#  25  Real Property Asset type               0 non-null      object
# dtypes: datetime64[ns](2), float64(4), int64(6), object(14)
# memory usage: 0.0+ bytes

# %%
blank_cells_sq_combined
# Out:
# Empty DataFrame
# Columns: [date, location, sq_ft, description, value, savings, agency, City, State, Location Code, Real Property Asset Name, Installation Name, Federal Leased Code, GSA Region, Street Address, Zip Code, Latitude, Longitude, Building Rentable Square Feet, Available Square Feet, Congressional District, Congressional District Representative, Lease Number, Lease Effective Date, Lease Expiration Date, Real Property Asset type]
# Index: []

# %%
with pd.ExcelWriter('politico_4-13_questions_doge_leases_data.xlsx') as writer:
    filtered_unclear_doge_leases.to_excel(writer, sheet_name='Sheet1', index=False) 
    filteredsq_unclear_combined.to_excel(writer, sheet_name='Sheet2', index=False) 
    blank_cells.to_excel(writer, sheet_name='Sheet3', index=False) 
    blank_cells_sq_combined.to_excel(writer, sheet_name='Sheet4', index=False)

# %%
with pd.ExcelWriter('politico_4-22_doge_dot_leases_data.xlsx') as writer:
    doge_dot_leases.to_excel(writer, sheet_name='Sheet1', index=False) 
    filteredsq_combined_gsa_doge.to_excel(writer, sheet_name='Sheet2', index=False)

# %%
file1 = "/Users/sogozalek/Desktop/Python/politico_4-13_doge_dot_leases_data.xlsx"

# %%
file2 = "/Users/sogozalek/politico_4-22_doge_dot_leases_data.xlsx"

# %%
df1 = pd.read_excel(file1, sheet_name="filteredsq_combined_gsa_doge")

# %%
df2 = pd.read_excel(file2, sheet_name="Sheet2")

# %%
if df1.shape != df2.shape:
    print("⚠️ The files have different dimensions!")
else:
    comparison = df1.compare(df2)

    if comparison.empty:
        print("✅ The spreadsheets are identical.")
    else:
        print("❌ Differences found:")
        print(comparison)
# Out:
# ✅ The spreadsheets are identical.
